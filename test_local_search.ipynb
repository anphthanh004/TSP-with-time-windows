# %%
from src.GA.ga_initialization import *
from src.GA.load_data_ga import load_data, load_output
from src.GA.ga_structures import Individual, Problem
from src.GA.ga_operators import *
from src.GA.ga_evolution_algorithm import run_genetic_algorithm
# from src.GA.lsv4 import local_search_softTW_first_improvement

# %%
import numpy as np

# %%
# data = load_data('dataset_hustack/input/100.txt')
# best_solution = load_output('dataset_hustack/input/100.txt', 'dataset_hustack/output/100-bestSolution.txt')

# %%
data = load_data('dataset/hustack/input/200.txt')
best_solution = load_output('dataset/hustack/input/200.txt', 'dataset/hustack/output/200-bestSolution.txt')

# %%
problem = Problem(num_request=data[0],
                  request=data[1], 
                  time_matrix=np.array(data[2]))

# %%
best_solution.calObjective()
# print(best_solution.total_service_time)
# Out:
# np.float64(103560.0)

# %%
cal_std_fitness([best_solution])

# %%
print("---> Fittest individual: ", best_solution.fitness)
print("-----Corresponding to the best individual-----")
print("---> Route:",  best_solution.route)
print(sum(best_solution.route_computing[0]))
# Index 3: Total time (Scalar)
print("---> Total service time: ", best_solution.route_computing[3]) 

# Index 4: Lateness (List) -> dùng để đếm số lần vi phạm
print("Number of time window violations: ", sum(1 for x in best_solution.route_computing[4] if x != 0.0))

# Index 5: Total Lateness (Scalar)
print("Total time of late arrivals: ", best_solution.route_computing[5])

# Index 6: Wait (List) -> dùng để đếm số lần đến sớm
print("Number of arrivals ealier than opening time: ", sum(1 for x in best_solution.route_computing[6] if x != 0))

# Index 7: Total Wait (Scalar)
print("Total time of arrivals ealier than opening time:", best_solution.route_computing[7])
# Out:
# ---> Fittest individual:  103560.0
# -----Corresponding to the best individual-----
# ---> Route: [54, 92, 148, 4, 64, 149, 133, 126, 89, 86, 49, 142, 76, 105, 41, 162, 178, 39, 198, 98, 169, 195, 110, 100, 165, 193, 172, 163, 29, 6, 19, 189, 137, 34, 179, 67, 40, 157, 11, 158, 1, 108, 43, 174, 136, 93, 143, 48, 44, 182, 150, 197, 53, 97, 71, 102, 88, 138, 109, 16, 46, 183, 63, 69, 5, 130, 60, 3, 68, 166, 2, 171, 73, 116, 200, 127, 77, 177, 38, 140, 81, 160, 134, 84, 156, 164, 87, 57, 199, 90, 91, 117, 28, 94, 95, 112, 78, 188, 192, 21, 155, 120, 75, 14, 35, 83, 107, 196, 10, 52, 111, 118, 42, 151, 186, 167, 32, 51, 119, 170, 181, 122, 66, 194, 125, 132, 13, 9, 173, 8, 131, 61, 7, 185, 146, 70, 33, 103, 139, 82, 141, 129, 47, 22, 176, 135, 147, 36, 101, 45, 123, 25, 24, 154, 121, 15, 99, 153, 37, 144, 161, 96, 80, 59, 114, 56, 159, 17, 12, 106, 55, 65, 115, 152, 175, 20, 124, 168, 26, 31, 62, 50, 74, 184, 27, 113, 30, 79, 187, 190, 191, 128, 58, 85, 104, 180, 145, 72, 23, 18]
# 97720
# ---> Total service time:  101539
# Number of time window violations:  0
# Total time of late arrivals:  0.0
# Number of arrivals ealier than opening time:  124
# Total time of arrivals ealier than opening time: 584.0

# %%
# gen_type = 'random'
# gen_type = 'greedy'
pop_size = 100
c_rate = 0.8
m_rate = 0.2
generations = 300
maximum_loop = 100

# %%
params ={
    # "fmethod": 'std', # std, ranking, distribution
    # "fmethod": 'ranking', # std, ranking, distribution
    # "fmethod": 'distribution', # std, ranking, distribution
    # "smethod": 'tournament', # tournament, roulette, random, ranking
    "smethod": 'roulette', # tournament, roulette, random, ranking
    "cmethod": 'ox', # ox, pmx, cx
    # "mmethod": 'inversion', # inversion, swap, scramble
    # "mmethod": 'scramble', # inversion, swap, scramble
    "mmethod": 'swap', # inversion, swap, scramble
    # "svmethod": 'tournament', # tournament, truncation, sus, linear
    "svmethod": 'sus', # tournament, truncation, sus, linear
    
    # "ranking_f_parameter": 0.5, # dùng cho ranking trong calculate_fitness
    
    "tourn_s_parameter": 4, # dùng cho tournament trong select_parents
    "ranking_s_parameter": 3, # dùng cho ranking trong select_parents
    
    "trunc_sv_parameter": 0.5, # dùng cho truncation trong apply_sv_selection
    # "linear_sv_parameter": 1.5, # dùng cho linear trong apply_sv_selection
    "tourn_sv_parameter": 4, # dùng cho tournament trong apply_sv_selection
    
    "gen_type": 'greedy', # loại khởi tạo greedy
    "greedy_rate": 0.5, # tỉ lệ các cá thể được khởi tạo greedy trong quần thể ban đầu
    "search_size": 2, # số lượng hàng xóm xét tại mỗi điểm đang đứng mà sẽ lựa chọn một trong số chúng để đến trong lộ trình tham lam
    
    # "imp_type": 'first_improvement',
    "ls_rate" : 0.1,
    "max_iter" : 10
}

# %%
from src.GA.local_search import local_search_softTW_first_improvement
test_indi = Individual(problem)
test_indi.route = list(range(1, problem.num_request+1))
improve_indi, progress = local_search_softTW_first_improvement(test_indi)
print(improve_indi.fitness)
# print(progress)
for i, p in enumerate(progress):
    print(i)
    print(p)
# Out:
# 104250.0
# 0
# {'time': 0.009004399995319545, 'iteration': 1, 'move': 'relocate', 'i': 59, 'j': 70, 'old_cost': np.float64(18409650060.0), 'new_cost': np.float64(18385850840.0), 'improvement': np.float64(23799220.0)}
# 1
# {'time': 0.010193900001468137, 'iteration': 1, 'move': 'swap', 'i': 128, 'j': 183, 'old_cost': np.float64(18385850840.0), 'new_cost': np.float64(18384250710.0), 'improvement': np.float64(1600130.0)}
# 2
# {'time': 0.010906899988185614, 'iteration': 1, 'move': '2-opt', 'i': 86, 'j': 89, 'old_cost': np.float64(18384250710.0), 'new_cost': np.float64(18347635470.0), 'improvement': np.float64(36615240.0)}
# 3
# {'time': 0.014559500006726012, 'iteration': 2, 'move': 'swap', 'i': 132, 'j': 149, 'old_cost': np.float64(18347635470.0), 'new_cost': np.float64(18323040130.0), 'improvement': np.float64(24595340.0)}
# 4
# {'time': 0.017430300009436905, 'iteration': 2, 'move': '2-opt', 'i': 36, 'j': 37, 'old_cost': np.float64(18323040130.0), 'new_cost': np.float64(18266084970.0), 'improvement': np.float64(56955160.0)}
# 5
# {'time': 0.033375300001353025, 'iteration': 2, 'move': 'relocate', 'i': 36, 'j': 13, 'old_cost': np.float64(18266084970.0), 'new_cost': np.float64(18230361170.0), 'improvement': np.float64(35723800.0)}
# 6
# {'time': 0.036187499994412065, 'iteration': 3, 'move': '2-opt', 'i': 112, 'j': 126, 'old_cost': np.float64(18230361170.0), 'new_cost': np.float64(18203181130.0), 'improvement': np.float64(27180040.0)}
# 7
# {'time': 0.04113100000540726, 'iteration': 3, 'move': 'relocate', 'i': 112, 'j': 108, 'old_cost': np.float64(18203181130.0), 'new_cost': np.float64(18199515840.0), 'improvement': np.float64(3665290.0)}
# 8
# {'time': 0.04757719999179244, 'iteration': 3, 'move': 'swap', 'i': 110, 'j': 116, 'old_cost': np.float64(18199515840.0), 'new_cost': np.float64(18121789860.0), 'improvement': np.float64(77725980.0)}
# 9
# {'time': 0.05290229999809526, 'iteration': 4, 'move': 'relocate', 'i': 133, 'j': 116, 'old_cost': np.float64(18121789860.0), 'new_cost': np.float64(18102414460.0), 'improvement': np.float64(19375400.0)}
# 10
# {'time': 0.05655020000995137, 'iteration': 4, 'move': 'swap', 'i': 105, 'j': 149, 'old_cost': np.float64(18102414460.0), 'new_cost': np.float64(18088459540.0), 'improvement': np.float64(13954920.0)}
# 11
# {'time': 0.06937990000005811, 'iteration': 4, 'move': '2-opt', 'i': 114, 'j': 129, 'old_cost': np.float64(18088459540.0), 'new_cost': np.float64(18074809290.0), 'improvement': np.float64(13650250.0)}
# 12
# {'time': 0.07377089999499731, 'iteration': 5, 'move': 'swap', 'i': 60, 'j': 71, 'old_cost': np.float64(18074809290.0), 'new_cost': np.float64(18052534190.0), 'improvement': np.float64(22275100.0)}
# 13
# {'time': 0.09686650001094677, 'iteration': 5, 'move': '2-opt', 'i': 24, 'j': 174, 'old_cost': np.float64(18052534190.0), 'new_cost': np.float64(18001339660.0), 'improvement': np.float64(51194530.0)}
# 14
# {'time': 0.10058160001062788, 'iteration': 5, 'move': 'relocate', 'i': 24, 'j': 15, 'old_cost': np.float64(18001339660.0), 'new_cost': np.float64(17977819210.0), 'improvement': np.float64(23520450.0)}
# 15
# {'time': 0.10186809999868274, 'iteration': 6, 'move': '2-opt', 'i': 134, 'j': 143, 'old_cost': np.float64(17977819210.0), 'new_cost': np.float64(17972919230.0), 'improvement': np.float64(4899980.0)}
# 16
# {'time': 0.10439900000346825, 'iteration': 6, 'move': 'relocate', 'i': 134, 'j': 76, 'old_cost': np.float64(17972919230.0), 'new_cost': np.float64(17937179060.0), 'improvement': np.float64(35740170.0)}
# 17
# {'time': 0.10588950000237674, 'iteration': 6, 'move': 'swap', 'i': 52, 'j': 61, 'old_cost': np.float64(17937179060.0), 'new_cost': np.float64(17891273650.0), 'improvement': np.float64(45905410.0)}
# 18
# {'time': 0.10922189999837428, 'iteration': 7, 'move': 'relocate', 'i': 185, 'j': 187, 'old_cost': np.float64(17891273650.0), 'new_cost': np.float64(17887493510.0), 'improvement': np.float64(3780140.0)}
# 19
# {'time': 0.11038759999792092, 'iteration': 7, 'move': 'swap', 'i': 58, 'j': 112, 'old_cost': np.float64(17887493510.0), 'new_cost': np.float64(17861813260.0), 'improvement': np.float64(25680250.0)}
# 20
# {'time': 0.11136690000421368, 'iteration': 7, 'move': '2-opt', 'i': 82, 'j': 90, 'old_cost': np.float64(17861813260.0), 'new_cost': np.float64(17763312490.0), 'improvement': np.float64(98500770.0)}
# 21
# {'time': 0.12631679998594336, 'iteration': 8, 'move': 'swap', 'i': 25, 'j': 45, 'old_cost': np.float64(17763312490.0), 'new_cost': np.float64(17707482110.0), 'improvement': np.float64(55830380.0)}
# 22
# {'time': 0.12734460001229309, 'iteration': 8, 'move': '2-opt', 'i': 101, 'j': 155, 'old_cost': np.float64(17707482110.0), 'new_cost': np.float64(17686022510.0), 'improvement': np.float64(21459600.0)}
# 23
# {'time': 0.14497590000974014, 'iteration': 8, 'move': 'relocate', 'i': 101, 'j': 19, 'old_cost': np.float64(17686022510.0), 'new_cost': np.float64(17650525830.0), 'improvement': np.float64(35496680.0)}
# 24
# {'time': 0.14971399999922141, 'iteration': 9, 'move': '2-opt', 'i': 35, 'j': 107, 'old_cost': np.float64(17650525830.0), 'new_cost': np.float64(17554915720.0), 'improvement': np.float64(95610110.0)}
# 25
# {'time': 0.23498400000971742, 'iteration': 10, 'move': 'relocate', 'i': 139, 'j': 149, 'old_cost': np.float64(17554915720.0), 'new_cost': np.float64(17550055610.0), 'improvement': np.float64(4860110.0)}
# 26
# {'time': 0.2362002999871038, 'iteration': 10, 'move': 'swap', 'i': 37, 'j': 81, 'old_cost': np.float64(17550055610.0), 'new_cost': np.float64(17265003690.0), 'improvement': np.float64(285051920.0)}
# 27
# {'time': 0.23845380000420846, 'iteration': 10, 'move': '2-opt', 'i': 84, 'j': 165, 'old_cost': np.float64(17265003690.0), 'new_cost': np.float64(17263169990.0), 'improvement': np.float64(1833700.0)}
# 28
# {'time': 0.2440348000091035, 'iteration': 11, 'move': 'swap', 'i': 0, 'j': 117, 'old_cost': np.float64(17263169990.0), 'new_cost': np.float64(17238440580.0), 'improvement': np.float64(24729410.0)}
# 29
# {'time': 0.24516220000805333, 'iteration': 11, 'move': '2-opt', 'i': 61, 'j': 64, 'old_cost': np.float64(17238440580.0), 'new_cost': np.float64(17213884630.0), 'improvement': np.float64(24555950.0)}
# 30
# {'time': 0.25064139999449253, 'iteration': 11, 'move': 'relocate', 'i': 61, 'j': 49, 'old_cost': np.float64(17213884630.0), 'new_cost': np.float64(17197589550.0), 'improvement': np.float64(16295080.0)}
# 31
# {'time': 0.2545788999996148, 'iteration': 12, 'move': '2-opt', 'i': 136, 'j': 197, 'old_cost': np.float64(17197589550.0), 'new_cost': np.float64(17126239800.0), 'improvement': np.float64(71349750.0)}
# 32
# {'time': 0.2835477000044193, 'iteration': 12, 'move': 'swap', 'i': 81, 'j': 99, 'old_cost': np.float64(17126239800.0), 'new_cost': np.float64(17113138820.0), 'improvement': np.float64(13100980.0)}
# 33
# {'time': 0.2853239999967627, 'iteration': 13, 'move': 'relocate', 'i': 104, 'j': 127, 'old_cost': np.float64(17113138820.0), 'new_cost': np.float64(17101028700.0), 'improvement': np.float64(12110120.0)}
# 34
# {'time': 0.2861202000058256, 'iteration': 13, 'move': 'swap', 'i': 8, 'j': 21, 'old_cost': np.float64(17101028700.0), 'new_cost': np.float64(17088696250.0), 'improvement': np.float64(12332450.0)}
# 35
# {'time': 0.28847219998715445, 'iteration': 14, 'move': 'swap', 'i': 89, 'j': 104, 'old_cost': np.float64(17088696250.0), 'new_cost': np.float64(17075976130.0), 'improvement': np.float64(12720120.0)}
# 36
# {'time': 0.28905359999043867, 'iteration': 14, 'move': '2-opt', 'i': 144, 'j': 170, 'old_cost': np.float64(17075976130.0), 'new_cost': np.float64(17049835260.0), 'improvement': np.float64(26140870.0)}
# 37
# {'time': 0.2917021999892313, 'iteration': 14, 'move': 'relocate', 'i': 144, 'j': 129, 'old_cost': np.float64(17049835260.0), 'new_cost': np.float64(17048390660.0), 'improvement': np.float64(1444600.0)}
# 38
# {'time': 0.2943244999914896, 'iteration': 15, 'move': '2-opt', 'i': 9, 'j': 148, 'old_cost': np.float64(17048390660.0), 'new_cost': np.float64(15968838850.0), 'improvement': np.float64(1079551810.0)}
# 39
# {'time': 0.38509480000357144, 'iteration': 16, 'move': 'relocate', 'i': 103, 'j': 58, 'old_cost': np.float64(15968838850.0), 'new_cost': np.float64(15964563970.0), 'improvement': np.float64(4274880.0)}
# 40
# {'time': 0.38542509998660535, 'iteration': 16, 'move': 'swap', 'i': 174, 'j': 184, 'old_cost': np.float64(15964563970.0), 'new_cost': np.float64(15948067560.0), 'improvement': np.float64(16496410.0)}
# 41
# {'time': 0.38709460000973195, 'iteration': 16, 'move': '2-opt', 'i': 20, 'j': 32, 'old_cost': np.float64(15948067560.0), 'new_cost': np.float64(15783612520.0), 'improvement': np.float64(164455040.0)}
# 42
# {'time': 0.38939130000653677, 'iteration': 17, 'move': 'swap', 'i': 182, 'j': 185, 'old_cost': np.float64(15783612520.0), 'new_cost': np.float64(15782967530.0), 'improvement': np.float64(644990.0)}
# 43
# {'time': 0.39028930000495166, 'iteration': 17, 'move': '2-opt', 'i': 105, 'j': 156, 'old_cost': np.float64(15782967530.0), 'new_cost': np.float64(15742016990.0), 'improvement': np.float64(40950540.0)}
# 44
# {'time': 0.40161850000731647, 'iteration': 17, 'move': 'relocate', 'i': 105, 'j': 6, 'old_cost': np.float64(15742016990.0), 'new_cost': np.float64(15697494760.0), 'improvement': np.float64(44522230.0)}
# 45
# {'time': 0.4036449000122957, 'iteration': 18, 'move': '2-opt', 'i': 139, 'j': 145, 'old_cost': np.float64(15697494760.0), 'new_cost': np.float64(15681544500.0), 'improvement': np.float64(15950260.0)}
# 46
# {'time': 0.40462049999041483, 'iteration': 18, 'move': 'relocate', 'i': 139, 'j': 116, 'old_cost': np.float64(15681544500.0), 'new_cost': np.float64(15643744010.0), 'improvement': np.float64(37800490.0)}
# 47
# {'time': 0.4089647000073455, 'iteration': 18, 'move': 'swap', 'i': 34, 'j': 177, 'old_cost': np.float64(15643744010.0), 'new_cost': np.float64(15642394410.0), 'improvement': np.float64(1349600.0)}
# 48
# {'time': 0.4104882999963593, 'iteration': 19, 'move': 'relocate', 'i': 85, 'j': 93, 'old_cost': np.float64(15642394410.0), 'new_cost': np.float64(15606084090.0), 'improvement': np.float64(36310320.0)}
# 49
# {'time': 0.44056399998953566, 'iteration': 19, 'move': '2-opt', 'i': 5, 'j': 80, 'old_cost': np.float64(15606084090.0), 'new_cost': np.float64(15572865880.0), 'improvement': np.float64(33218210.0)}
# 50
# {'time': 0.4425013999862131, 'iteration': 20, 'move': 'swap', 'i': 15, 'j': 134, 'old_cost': np.float64(15572865880.0), 'new_cost': np.float64(15570541120.0), 'improvement': np.float64(2324760.0)}
# 51
# {'time': 0.4463654000137467, 'iteration': 20, 'move': '2-opt', 'i': 16, 'j': 53, 'old_cost': np.float64(15570541120.0), 'new_cost': np.float64(15441545960.0), 'improvement': np.float64(128995160.0)}
# 52
# {'time': 0.4958291999937501, 'iteration': 21, 'move': '2-opt', 'i': 106, 'j': 156, 'old_cost': np.float64(15441545960.0), 'new_cost': np.float64(15378295770.0), 'improvement': np.float64(63250190.0)}
# 53
# {'time': 0.5022164999973029, 'iteration': 21, 'move': 'relocate', 'i': 106, 'j': 21, 'old_cost': np.float64(15378295770.0), 'new_cost': np.float64(15334819270.0), 'improvement': np.float64(43476500.0)}
# 54
# {'time': 0.5450315999914892, 'iteration': 22, 'move': 'relocate', 'i': 23, 'j': 34, 'old_cost': np.float64(15334819270.0), 'new_cost': np.float64(15332209000.0), 'improvement': np.float64(2610270.0)}
# 55
# {'time': 0.5499277999915648, 'iteration': 22, 'move': 'swap', 'i': 27, 'j': 74, 'old_cost': np.float64(15332209000.0), 'new_cost': np.float64(15312947590.0), 'improvement': np.float64(19261410.0)}
# 56
# {'time': 0.5627583999885246, 'iteration': 23, 'move': 'swap', 'i': 192, 'j': 195, 'old_cost': np.float64(15312947590.0), 'new_cost': np.float64(15308099920.0), 'improvement': np.float64(4847670.0)}
# 57
# {'time': 0.5629717000119854, 'iteration': 23, 'move': '2-opt', 'i': 164, 'j': 170, 'old_cost': np.float64(15308099920.0), 'new_cost': np.float64(15289539470.0), 'improvement': np.float64(18560450.0)}
# 58
# {'time': 0.5655904999875929, 'iteration': 23, 'move': 'relocate', 'i': 164, 'j': 16, 'old_cost': np.float64(15289539470.0), 'new_cost': np.float64(15238570400.0), 'improvement': np.float64(50969070.0)}
# 59
# {'time': 0.5820575999969151, 'iteration': 24, 'move': '2-opt', 'i': 2, 'j': 6, 'old_cost': np.float64(15238570400.0), 'new_cost': np.float64(15235308500.0), 'improvement': np.float64(3261900.0)}
# 60
# {'time': 0.6236954999912996, 'iteration': 24, 'move': 'swap', 'i': 93, 'j': 95, 'old_cost': np.float64(15235308500.0), 'new_cost': np.float64(15226520290.0), 'improvement': np.float64(8788210.0)}
# 61
# {'time': 0.625006599992048, 'iteration': 25, 'move': 'relocate', 'i': 196, 'j': 90, 'old_cost': np.float64(15226520290.0), 'new_cost': np.float64(15222220080.0), 'improvement': np.float64(4300210.0)}
# 62
# {'time': 0.6252004000125453, 'iteration': 25, 'move': 'swap', 'i': 162, 'j': 169, 'old_cost': np.float64(15222220080.0), 'new_cost': np.float64(15217730140.0), 'improvement': np.float64(4489940.0)}
# 63
# {'time': 0.6254119999939576, 'iteration': 25, 'move': '2-opt', 'i': 178, 'j': 194, 'old_cost': np.float64(15217730140.0), 'new_cost': np.float64(15216250210.0), 'improvement': np.float64(1479930.0)}
# 64
# {'time': 0.6269777000125032, 'iteration': 26, 'move': 'swap', 'i': 136, 'j': 183, 'old_cost': np.float64(15216250210.0), 'new_cost': np.float64(15206315560.0), 'improvement': np.float64(9934650.0)}
# 65
# {'time': 0.6272285000013653, 'iteration': 26, 'move': '2-opt', 'i': 152, 'j': 182, 'old_cost': np.float64(15206315560.0), 'new_cost': np.float64(15199540500.0), 'improvement': np.float64(6775060.0)}
# 66
# {'time': 0.627819899993483, 'iteration': 26, 'move': 'relocate', 'i': 152, 'j': 67, 'old_cost': np.float64(15199540500.0), 'new_cost': np.float64(15172999820.0), 'improvement': np.float64(26540680.0)}
# 67
# {'time': 0.6320839000109117, 'iteration': 27, 'move': '2-opt', 'i': 139, 'j': 147, 'old_cost': np.float64(15172999820.0), 'new_cost': np.float64(15169969730.0), 'improvement': np.float64(3030090.0)}
# 68
# {'time': 0.6344453000056092, 'iteration': 27, 'move': 'relocate', 'i': 139, 'j': 138, 'old_cost': np.float64(15169969730.0), 'new_cost': np.float64(15162709650.0), 'improvement': np.float64(7260080.0)}
# 69
# {'time': 0.6360079000005499, 'iteration': 27, 'move': 'swap', 'i': 61, 'j': 63, 'old_cost': np.float64(15162709650.0), 'new_cost': np.float64(15158629710.0), 'improvement': np.float64(4079940.0)}
# 70
# {'time': 0.6378541000012774, 'iteration': 28, 'move': 'relocate', 'i': 109, 'j': 95, 'old_cost': np.float64(15158629710.0), 'new_cost': np.float64(15131909480.0), 'improvement': np.float64(26720230.0)}
# 71
# {'time': 0.6396749000123236, 'iteration': 28, 'move': '2-opt', 'i': 53, 'j': 130, 'old_cost': np.float64(15131909480.0), 'new_cost': np.float64(15107489570.0), 'improvement': np.float64(24419910.0)}
# 72
# {'time': 0.6416935999877751, 'iteration': 29, 'move': 'swap', 'i': 151, 'j': 159, 'old_cost': np.float64(15107489570.0), 'new_cost': np.float64(15095089270.0), 'improvement': np.float64(12400300.0)}
# 73
# {'time': 0.6420763999922201, 'iteration': 29, 'move': '2-opt', 'i': 157, 'j': 198, 'old_cost': np.float64(15095089270.0), 'new_cost': np.float64(15028474630.0), 'improvement': np.float64(66614640.0)}
# 74
# {'time': 0.6476440000114962, 'iteration': 29, 'move': 'relocate', 'i': 157, 'j': 3, 'old_cost': np.float64(15028474630.0), 'new_cost': np.float64(14989160580.0), 'improvement': np.float64(39314050.0)}
# 75
# {'time': 0.6492521000036504, 'iteration': 30, 'move': '2-opt', 'i': 172, 'j': 197, 'old_cost': np.float64(14989160580.0), 'new_cost': np.float64(14980230360.0), 'improvement': np.float64(8930220.0)}
# 76
# {'time': 0.6503998000116553, 'iteration': 30, 'move': 'relocate', 'i': 172, 'j': 16, 'old_cost': np.float64(14980230360.0), 'new_cost': np.float64(14922809940.0), 'improvement': np.float64(57420420.0)}
# 77
# {'time': 0.6636526999936905, 'iteration': 31, 'move': 'relocate', 'i': 85, 'j': 26, 'old_cost': np.float64(14922809940.0), 'new_cost': np.float64(14871502410.0), 'improvement': np.float64(51307530.0)}
# 78
# {'time': 0.6727003999985754, 'iteration': 31, 'move': '2-opt', 'i': 59, 'j': 121, 'old_cost': np.float64(14871502410.0), 'new_cost': np.float64(14828369290.0), 'improvement': np.float64(43133120.0)}
# 79
# {'time': 0.6751613999949768, 'iteration': 32, 'move': 'swap', 'i': 132, 'j': 146, 'old_cost': np.float64(14828369290.0), 'new_cost': np.float64(14806958780.0), 'improvement': np.float64(21410510.0)}
# 80
# {'time': 0.681935100001283, 'iteration': 32, 'move': '2-opt', 'i': 78, 'j': 98, 'old_cost': np.float64(14806958780.0), 'new_cost': np.float64(14796318890.0), 'improvement': np.float64(10639890.0)}
# 81
# {'time': 0.6835196999891195, 'iteration': 32, 'move': 'relocate', 'i': 78, 'j': 6, 'old_cost': np.float64(14796318890.0), 'new_cost': np.float64(14759758600.0), 'improvement': np.float64(36560290.0)}
# 82
# {'time': 0.6918626000115182, 'iteration': 33, 'move': '2-opt', 'i': 91, 'j': 128, 'old_cost': np.float64(14759758600.0), 'new_cost': np.float64(14743418690.0), 'improvement': np.float64(16339910.0)}
# 83
# {'time': 0.7066539000079501, 'iteration': 33, 'move': 'relocate', 'i': 91, 'j': 48, 'old_cost': np.float64(14743418690.0), 'new_cost': np.float64(14740488600.0), 'improvement': np.float64(2930090.0)}
# 84
# {'time': 0.7078423000057228, 'iteration': 33, 'move': 'swap', 'i': 62, 'j': 81, 'old_cost': np.float64(14740488600.0), 'new_cost': np.float64(14727368390.0), 'improvement': np.float64(13120210.0)}
# 85
# {'time': 0.7092326999991201, 'iteration': 34, 'move': 'relocate', 'i': 101, 'j': 105, 'old_cost': np.float64(14727368390.0), 'new_cost': np.float64(14676602900.0), 'improvement': np.float64(50765490.0)}
# 86
# {'time': 0.7098480999993626, 'iteration': 34, 'move': 'swap', 'i': 130, 'j': 186, 'old_cost': np.float64(14676602900.0), 'new_cost': np.float64(14670808190.0), 'improvement': np.float64(5794710.0)}
# 87
# {'time': 0.7140481999958865, 'iteration': 34, 'move': '2-opt', 'i': 102, 'j': 106, 'old_cost': np.float64(14670808190.0), 'new_cost': np.float64(14653427650.0), 'improvement': np.float64(17380540.0)}
# 88
# {'time': 0.7164373999985401, 'iteration': 35, 'move': 'swap', 'i': 17, 'j': 20, 'old_cost': np.float64(14653427650.0), 'new_cost': np.float64(14652767290.0), 'improvement': np.float64(660360.0)}
# 89
# {'time': 0.7179073999868706, 'iteration': 35, 'move': '2-opt', 'i': 114, 'j': 125, 'old_cost': np.float64(14652767290.0), 'new_cost': np.float64(14612107220.0), 'improvement': np.float64(40660070.0)}
# 90
# {'time': 0.7296488000138197, 'iteration': 35, 'move': 'relocate', 'i': 114, 'j': 39, 'old_cost': np.float64(14612107220.0), 'new_cost': np.float64(14605968240.0), 'improvement': np.float64(6138980.0)}
# 91
# {'time': 0.7316131000116002, 'iteration': 36, 'move': '2-opt', 'i': 158, 'j': 193, 'old_cost': np.float64(14605968240.0), 'new_cost': np.float64(14554658150.0), 'improvement': np.float64(51310090.0)}
# 92
# {'time': 0.7337780999951065, 'iteration': 36, 'move': 'relocate', 'i': 158, 'j': 7, 'old_cost': np.float64(14554658150.0), 'new_cost': np.float64(14455541760.0), 'improvement': np.float64(99116390.0)}
# 93
# {'time': 0.7384064999932889, 'iteration': 37, 'move': 'relocate', 'i': 163, 'j': 160, 'old_cost': np.float64(14455541760.0), 'new_cost': np.float64(14432101090.0), 'improvement': np.float64(23440670.0)}
# 94
# {'time': 0.7764151000010315, 'iteration': 38, 'move': 'swap', 'i': 183, 'j': 187, 'old_cost': np.float64(14432101090.0), 'new_cost': np.float64(14430160900.0), 'improvement': np.float64(1940190.0)}
# 95
# {'time': 0.7767252000048757, 'iteration': 38, 'move': '2-opt', 'i': 162, 'j': 170, 'old_cost': np.float64(14430160900.0), 'new_cost': np.float64(14411130640.0), 'improvement': np.float64(19030260.0)}
# 96
# {'time': 0.7775324000103865, 'iteration': 38, 'move': 'relocate', 'i': 162, 'j': 13, 'old_cost': np.float64(14411130640.0), 'new_cost': np.float64(14329166510.0), 'improvement': np.float64(81964130.0)}
# 97
# {'time': 0.7792455999879166, 'iteration': 39, 'move': '2-opt', 'i': 103, 'j': 145, 'old_cost': np.float64(14329166510.0), 'new_cost': np.float64(14313516250.0), 'improvement': np.float64(15650260.0)}
# 98
# {'time': 0.7817785000079311, 'iteration': 39, 'move': 'relocate', 'i': 103, 'j': 46, 'old_cost': np.float64(14313516250.0), 'new_cost': np.float64(14265356090.0), 'improvement': np.float64(48160160.0)}
# 99
# {'time': 0.7843940999882761, 'iteration': 39, 'move': 'swap', 'i': 31, 'j': 51, 'old_cost': np.float64(14265356090.0), 'new_cost': np.float64(14254454410.0), 'improvement': np.float64(10901680.0)}
# 100
# {'time': 0.7910321000090335, 'iteration': 40, 'move': 'relocate', 'i': 19, 'j': 27, 'old_cost': np.float64(14254454410.0), 'new_cost': np.float64(14231258140.0), 'improvement': np.float64(23196270.0)}
# 101
# {'time': 0.7920862000028137, 'iteration': 40, 'move': 'swap', 'i': 105, 'j': 112, 'old_cost': np.float64(14231258140.0), 'new_cost': np.float64(14206233830.0), 'improvement': np.float64(25024310.0)}
# 102
# {'time': 0.8051351000030991, 'iteration': 40, 'move': '2-opt', 'i': 22, 'j': 78, 'old_cost': np.float64(14206233830.0), 'new_cost': np.float64(14030687730.0), 'improvement': np.float64(175546100.0)}
# 103
# {'time': 0.8068641999852844, 'iteration': 41, 'move': 'swap', 'i': 191, 'j': 195, 'old_cost': np.float64(14030687730.0), 'new_cost': np.float64(14030577750.0), 'improvement': np.float64(109980.0)}
# 104
# {'time': 0.8146555999992415, 'iteration': 41, 'move': '2-opt', 'i': 62, 'j': 73, 'old_cost': np.float64(14030577750.0), 'new_cost': np.float64(14019112600.0), 'improvement': np.float64(11465150.0)}
# 105
# {'time': 0.834981299994979, 'iteration': 41, 'move': 'relocate', 'i': 62, 'j': 12, 'old_cost': np.float64(14019112600.0), 'new_cost': np.float64(14010055440.0), 'improvement': np.float64(9057160.0)}
# 106
# {'time': 0.8365902999939863, 'iteration': 42, 'move': '2-opt', 'i': 71, 'j': 87, 'old_cost': np.float64(14010055440.0), 'new_cost': np.float64(13971575210.0), 'improvement': np.float64(38480230.0)}
# 107
# {'time': 0.8371818999876268, 'iteration': 42, 'move': 'relocate', 'i': 71, 'j': 63, 'old_cost': np.float64(13971575210.0), 'new_cost': np.float64(13937124890.0), 'improvement': np.float64(34450320.0)}
# 108
# {'time': 0.8579412999970373, 'iteration': 43, 'move': 'relocate', 'i': 180, 'j': 163, 'old_cost': np.float64(13937124890.0), 'new_cost': np.float64(13925864560.0), 'improvement': np.float64(11260330.0)}
# 109
# {'time': 0.8595126000000164, 'iteration': 43, 'move': 'swap', 'i': 72, 'j': 162, 'old_cost': np.float64(13925864560.0), 'new_cost': np.float64(13820003340.0), 'improvement': np.float64(105861220.0)}
# 110
# {'time': 0.8618181000056211, 'iteration': 44, 'move': 'swap', 'i': 118, 'j': 186, 'old_cost': np.float64(13820003340.0), 'new_cost': np.float64(13745702410.0), 'improvement': np.float64(74300930.0)}
# 111
# {'time': 0.8658972000121139, 'iteration': 44, 'move': '2-opt', 'i': 21, 'j': 88, 'old_cost': np.float64(13745702410.0), 'new_cost': np.float64(13648415570.0), 'improvement': np.float64(97286840.0)}
# 112
# {'time': 0.9190971000061836, 'iteration': 45, 'move': '2-opt', 'i': 68, 'j': 75, 'old_cost': np.float64(13648415570.0), 'new_cost': np.float64(13613385290.0), 'improvement': np.float64(35030280.0)}
# 113
# {'time': 0.9222293999919202, 'iteration': 45, 'move': 'relocate', 'i': 68, 'j': 0, 'old_cost': np.float64(13613385290.0), 'new_cost': np.float64(13550845020.0), 'improvement': np.float64(62540270.0)}
# 114
# {'time': 0.9388945999962743, 'iteration': 46, 'move': 'relocate', 'i': 15, 'j': 11, 'old_cost': np.float64(13550845020.0), 'new_cost': np.float64(13549829640.0), 'improvement': np.float64(1015380.0)}
# 115
# {'time': 0.9413678999990225, 'iteration': 46, 'move': 'swap', 'i': 46, 'j': 165, 'old_cost': np.float64(13549829640.0), 'new_cost': np.float64(13549355510.0), 'improvement': np.float64(474130.0)}
# 116
# {'time': 0.9417152999958489, 'iteration': 46, 'move': '2-opt', 'i': 166, 'j': 184, 'old_cost': np.float64(13549355510.0), 'new_cost': np.float64(13539064930.0), 'improvement': np.float64(10290580.0)}
# 117
# {'time': 0.9436106999928597, 'iteration': 47, 'move': 'swap', 'i': 120, 'j': 180, 'old_cost': np.float64(13539064930.0), 'new_cost': np.float64(13528505170.0), 'improvement': np.float64(10559760.0)}
# 118
# {'time': 0.9572424000070896, 'iteration': 47, 'move': '2-opt', 'i': 32, 'j': 88, 'old_cost': np.float64(13528505170.0), 'new_cost': np.float64(13368806940.0), 'improvement': np.float64(159698230.0)}
# 119
# {'time': 1.0081996000080835, 'iteration': 48, 'move': '2-opt', 'i': 78, 'j': 92, 'old_cost': np.float64(13368806940.0), 'new_cost': np.float64(13341076650.0), 'improvement': np.float64(27730290.0)}
# 120
# {'time': 1.0144567000097595, 'iteration': 48, 'move': 'relocate', 'i': 78, 'j': 93, 'old_cost': np.float64(13341076650.0), 'new_cost': np.float64(13323426520.0), 'improvement': np.float64(17650130.0)}
# 121
# {'time': 1.016674199985573, 'iteration': 48, 'move': 'swap', 'i': 81, 'j': 112, 'old_cost': np.float64(13323426520.0), 'new_cost': np.float64(13270410890.0), 'improvement': np.float64(53015630.0)}
# 122
# {'time': 1.0218646999855991, 'iteration': 49, 'move': 'relocate', 'i': 68, 'j': 80, 'old_cost': np.float64(13270410890.0), 'new_cost': np.float64(13260690830.0), 'improvement': np.float64(9720060.0)}
# 123
# {'time': 1.0495001999952365, 'iteration': 49, 'move': '2-opt', 'i': 103, 'j': 112, 'old_cost': np.float64(13260690830.0), 'new_cost': np.float64(13251965560.0), 'improvement': np.float64(8725270.0)}
# 124
# {'time': 1.0513102000113577, 'iteration': 50, 'move': 'swap', 'i': 49, 'j': 53, 'old_cost': np.float64(13251965560.0), 'new_cost': np.float64(13195765170.0), 'improvement': np.float64(56200390.0)}
# 125
# {'time': 1.0525482000084594, 'iteration': 50, 'move': '2-opt', 'i': 26, 'j': 42, 'old_cost': np.float64(13195765170.0), 'new_cost': np.float64(13173294980.0), 'improvement': np.float64(22470190.0)}
# 126
# {'time': 1.0755771000112873, 'iteration': 50, 'move': 'relocate', 'i': 26, 'j': 13, 'old_cost': np.float64(13173294980.0), 'new_cost': np.float64(13171325980.0), 'improvement': np.float64(1969000.0)}
# 127
# {'time': 1.077174100006232, 'iteration': 51, 'move': '2-opt', 'i': 57, 'j': 65, 'old_cost': np.float64(13171325980.0), 'new_cost': np.float64(13131075700.0), 'improvement': np.float64(40250280.0)}
# 128
# {'time': 1.0808176999853458, 'iteration': 51, 'move': 'relocate', 'i': 57, 'j': 53, 'old_cost': np.float64(13131075700.0), 'new_cost': np.float64(13123765660.0), 'improvement': np.float64(7310040.0)}
# 129
# {'time': 1.0845934000099078, 'iteration': 51, 'move': 'swap', 'i': 21, 'j': 33, 'old_cost': np.float64(13123765660.0), 'new_cost': np.float64(13058135320.0), 'improvement': np.float64(65630340.0)}
# 130
# {'time': 1.0910358999972232, 'iteration': 52, 'move': 'relocate', 'i': 93, 'j': 7, 'old_cost': np.float64(13058135320.0), 'new_cost': np.float64(12951256500.0), 'improvement': np.float64(106878820.0)}
# 131
# {'time': 1.1280010000045877, 'iteration': 53, 'move': 'swap', 'i': 67, 'j': 128, 'old_cost': np.float64(12951256500.0), 'new_cost': np.float64(12934491250.0), 'improvement': np.float64(16765250.0)}
# 132
# {'time': 1.1309361000021454, 'iteration': 53, 'move': '2-opt', 'i': 18, 'j': 21, 'old_cost': np.float64(12934491250.0), 'new_cost': np.float64(12809490170.0), 'improvement': np.float64(125001080.0)}
# 133
# {'time': 1.1330301999987569, 'iteration': 53, 'move': 'relocate', 'i': 18, 'j': 136, 'old_cost': np.float64(12809490170.0), 'new_cost': np.float64(12800244570.0), 'improvement': np.float64(9245600.0)}
# 134
# {'time': 1.134726899996167, 'iteration': 54, 'move': '2-opt', 'i': 59, 'j': 108, 'old_cost': np.float64(12800244570.0), 'new_cost': np.float64(12760749070.0), 'improvement': np.float64(39495500.0)}
# 135
# {'time': 1.1844815000076778, 'iteration': 55, 'move': 'relocate', 'i': 104, 'j': 132, 'old_cost': np.float64(12760749070.0), 'new_cost': np.float64(12758718950.0), 'improvement': np.float64(2030120.0)}
# 136
# {'time': 1.189999700000044, 'iteration': 55, 'move': 'swap', 'i': 44, 'j': 55, 'old_cost': np.float64(12758718950.0), 'new_cost': np.float64(12728378840.0), 'improvement': np.float64(30340110.0)}
# 137
# {'time': 1.1914335000037681, 'iteration': 55, 'move': '2-opt', 'i': 27, 'j': 36, 'old_cost': np.float64(12728378840.0), 'new_cost': np.float64(12559625980.0), 'improvement': np.float64(168752860.0)}
# 138
# {'time': 1.1966883999994025, 'iteration': 56, 'move': 'swap', 'i': 82, 'j': 173, 'old_cost': np.float64(12559625980.0), 'new_cost': np.float64(12557201320.0), 'improvement': np.float64(2424660.0)}
# 139
# {'time': 1.2005978999950457, 'iteration': 56, 'move': '2-opt', 'i': 125, 'j': 147, 'old_cost': np.float64(12557201320.0), 'new_cost': np.float64(12524905510.0), 'improvement': np.float64(32295810.0)}
# 140
# {'time': 1.203746199986199, 'iteration': 56, 'move': 'relocate', 'i': 125, 'j': 44, 'old_cost': np.float64(12524905510.0), 'new_cost': np.float64(12495468040.0), 'improvement': np.float64(29437470.0)}
# 141
# {'time': 1.2074939000012819, 'iteration': 57, 'move': '2-opt', 'i': 117, 'j': 132, 'old_cost': np.float64(12495468040.0), 'new_cost': np.float64(12447772410.0), 'improvement': np.float64(47695630.0)}
# 142
# {'time': 1.2538377000018954, 'iteration': 58, 'move': 'relocate', 'i': 81, 'j': 84, 'old_cost': np.float64(12447772410.0), 'new_cost': np.float64(12436932320.0), 'improvement': np.float64(10840090.0)}
# 143
# {'time': 1.2542313000012655, 'iteration': 58, 'move': 'swap', 'i': 122, 'j': 175, 'old_cost': np.float64(12436932320.0), 'new_cost': np.float64(12429936770.0), 'improvement': np.float64(6995550.0)}
# 144
# {'time': 1.2545678000024054, 'iteration': 58, 'move': '2-opt', 'i': 132, 'j': 150, 'old_cost': np.float64(12429936770.0), 'new_cost': np.float64(12419331840.0), 'improvement': np.float64(10604930.0)}
# 145
# {'time': 1.2643386000127066, 'iteration': 59, 'move': 'swap', 'i': 12, 'j': 19, 'old_cost': np.float64(12419331840.0), 'new_cost': np.float64(12418276300.0), 'improvement': np.float64(1055540.0)}
# 146
# {'time': 1.2802503000129946, 'iteration': 59, 'move': '2-opt', 'i': 36, 'j': 138, 'old_cost': np.float64(12418276300.0), 'new_cost': np.float64(12400939740.0), 'improvement': np.float64(17336560.0)}
# 147
# {'time': 1.4068672999856062, 'iteration': 59, 'move': 'relocate', 'i': 36, 'j': 18, 'old_cost': np.float64(12400939740.0), 'new_cost': np.float64(12400358720.0), 'improvement': np.float64(581020.0)}
# 148
# {'time': 1.4154635999875609, 'iteration': 60, 'move': '2-opt', 'i': 94, 'j': 105, 'old_cost': np.float64(12400358720.0), 'new_cost': np.float64(12394048680.0), 'improvement': np.float64(6310040.0)}
# 149
# {'time': 1.4181484000000637, 'iteration': 60, 'move': 'relocate', 'i': 94, 'j': 103, 'old_cost': np.float64(12394048680.0), 'new_cost': np.float64(12354263260.0), 'improvement': np.float64(39785420.0)}
# 150
# {'time': 1.424219800013816, 'iteration': 61, 'move': 'relocate', 'i': 107, 'j': 64, 'old_cost': np.float64(12354263260.0), 'new_cost': np.float64(12294197700.0), 'improvement': np.float64(60065560.0)}
# 151
# {'time': 1.5173886000120547, 'iteration': 61, 'move': '2-opt', 'i': 34, 'j': 45, 'old_cost': np.float64(12294197700.0), 'new_cost': np.float64(12281519910.0), 'improvement': np.float64(12677790.0)}
# 152
# {'time': 1.5236462999891955, 'iteration': 62, 'move': 'swap', 'i': 69, 'j': 75, 'old_cost': np.float64(12281519910.0), 'new_cost': np.float64(12216289390.0), 'improvement': np.float64(65230520.0)}
# 153
# {'time': 1.5793209999974351, 'iteration': 63, 'move': '2-opt', 'i': 14, 'j': 21, 'old_cost': np.float64(12216289390.0), 'new_cost': np.float64(12125758240.0), 'improvement': np.float64(90531150.0)}
# 154
# {'time': 1.6346070999861695, 'iteration': 64, 'move': 'relocate', 'i': 119, 'j': 89, 'old_cost': np.float64(12125758240.0), 'new_cost': np.float64(12088522840.0), 'improvement': np.float64(37235400.0)}
# 155
# {'time': 1.679377199994633, 'iteration': 65, 'move': 'swap', 'i': 183, 'j': 189, 'old_cost': np.float64(12088522840.0), 'new_cost': np.float64(12088402820.0), 'improvement': np.float64(120020.0)}
# 156
# {'time': 1.6902317999920342, 'iteration': 65, 'move': '2-opt', 'i': 74, 'j': 102, 'old_cost': np.float64(12088402820.0), 'new_cost': np.float64(12076482780.0), 'improvement': np.float64(11920040.0)}
# 157
# {'time': 1.693043100007344, 'iteration': 65, 'move': 'relocate', 'i': 74, 'j': 33, 'old_cost': np.float64(12076482780.0), 'new_cost': np.float64(12035826160.0), 'improvement': np.float64(40656620.0)}
# 158
# {'time': 1.701937400008319, 'iteration': 66, 'move': '2-opt', 'i': 12, 'j': 30, 'old_cost': np.float64(12035826160.0), 'new_cost': np.float64(12006861870.0), 'improvement': np.float64(28964290.0)}
# 159
# {'time': 1.754182500008028, 'iteration': 66, 'move': 'swap', 'i': 43, 'j': 55, 'old_cost': np.float64(12006861870.0), 'new_cost': np.float64(11990463280.0), 'improvement': np.float64(16398590.0)}
# 160
# {'time': 1.7559272999933455, 'iteration': 67, 'move': 'relocate', 'i': 146, 'j': 50, 'old_cost': np.float64(11990463280.0), 'new_cost': np.float64(11989458390.0), 'improvement': np.float64(1004890.0)}
# 161
# {'time': 1.7572169000050053, 'iteration': 67, 'move': 'swap', 'i': 111, 'j': 159, 'old_cost': np.float64(11989458390.0), 'new_cost': np.float64(11977923080.0), 'improvement': np.float64(11535310.0)}
# 162
# {'time': 1.7578219000133686, 'iteration': 67, 'move': '2-opt', 'i': 170, 'j': 176, 'old_cost': np.float64(11977923080.0), 'new_cost': np.float64(11976352680.0), 'improvement': np.float64(1570400.0)}
# 163
# {'time': 1.7591128000058234, 'iteration': 68, 'move': 'swap', 'i': 137, 'j': 169, 'old_cost': np.float64(11976352680.0), 'new_cost': np.float64(11959522930.0), 'improvement': np.float64(16829750.0)}
# 164
# {'time': 1.7796241999894846, 'iteration': 68, 'move': 'relocate', 'i': 97, 'j': 39, 'old_cost': np.float64(11959522930.0), 'new_cost': np.float64(11926435970.0), 'improvement': np.float64(33086960.0)}
# 165
# {'time': 1.7881239000125788, 'iteration': 69, 'move': '2-opt', 'i': 12, 'j': 30, 'old_cost': np.float64(11926435970.0), 'new_cost': np.float64(11897700680.0), 'improvement': np.float64(28735290.0)}
# 166
# {'time': 1.8354201999900397, 'iteration': 69, 'move': 'swap', 'i': 158, 'j': 173, 'old_cost': np.float64(11897700680.0), 'new_cost': np.float64(11887394880.0), 'improvement': np.float64(10305800.0)}
# 167
# {'time': 1.838299700000789, 'iteration': 70, 'move': 'relocate', 'i': 113, 'j': 111, 'old_cost': np.float64(11887394880.0), 'new_cost': np.float64(11884024850.0), 'improvement': np.float64(3370030.0)}
# 168
# {'time': 1.8785107999865431, 'iteration': 70, 'move': '2-opt', 'i': 87, 'j': 88, 'old_cost': np.float64(11884024850.0), 'new_cost': np.float64(11829804360.0), 'improvement': np.float64(54220490.0)}
# 169
# {'time': 1.8837838000035845, 'iteration': 71, 'move': 'swap', 'i': 104, 'j': 165, 'old_cost': np.float64(11829804360.0), 'new_cost': np.float64(11817709080.0), 'improvement': np.float64(12095280.0)}
# 170
# {'time': 1.8860917999991216, 'iteration': 71, 'move': 'relocate', 'i': 191, 'j': 11, 'old_cost': np.float64(11817709080.0), 'new_cost': np.float64(11716655890.0), 'improvement': np.float64(101053190.0)}
# 171
# {'time': 1.8901301999867428, 'iteration': 72, 'move': '2-opt', 'i': 134, 'j': 157, 'old_cost': np.float64(11716655890.0), 'new_cost': np.float64(11712410900.0), 'improvement': np.float64(4244990.0)}
# 172
# {'time': 1.8939190999954008, 'iteration': 72, 'move': 'relocate', 'i': 134, 'j': 23, 'old_cost': np.float64(11712410900.0), 'new_cost': np.float64(11659982010.0), 'improvement': np.float64(52428890.0)}
# 173
# {'time': 1.91464870001073, 'iteration': 73, 'move': 'relocate', 'i': 58, 'j': 77, 'old_cost': np.float64(11659982010.0), 'new_cost': np.float64(11625376710.0), 'improvement': np.float64(34605300.0)}
# 174
# {'time': 1.9179092000122182, 'iteration': 73, 'move': 'swap', 'i': 125, 'j': 136, 'old_cost': np.float64(11625376710.0), 'new_cost': np.float64(11614226390.0), 'improvement': np.float64(11150320.0)}
# 175
# {'time': 1.9191044000035618, 'iteration': 73, 'move': '2-opt', 'i': 65, 'j': 71, 'old_cost': np.float64(11614226390.0), 'new_cost': np.float64(11578131360.0), 'improvement': np.float64(36095030.0)}
# 176
# {'time': 1.9207517000031658, 'iteration': 74, 'move': 'swap', 'i': 119, 'j': 120, 'old_cost': np.float64(11578131360.0), 'new_cost': np.float64(11565276200.0), 'improvement': np.float64(12855160.0)}
# 177
# {'time': 1.9592515999975149, 'iteration': 74, 'move': 'relocate', 'i': 26, 'j': 7, 'old_cost': np.float64(11565276200.0), 'new_cost': np.float64(11552987040.0), 'improvement': np.float64(12289160.0)}
# 178
# {'time': 1.967972299986286, 'iteration': 75, 'move': '2-opt', 'i': 118, 'j': 123, 'old_cost': np.float64(11552987040.0), 'new_cost': np.float64(11548336990.0), 'improvement': np.float64(4650050.0)}
# 179
# {'time': 1.9693420999974478, 'iteration': 75, 'move': 'relocate', 'i': 118, 'j': 62, 'old_cost': np.float64(11548336990.0), 'new_cost': np.float64(11527101890.0), 'improvement': np.float64(21235100.0)}
# 180
# {'time': 2.0072918999940157, 'iteration': 76, 'move': 'relocate', 'i': 154, 'j': 135, 'old_cost': np.float64(11527101890.0), 'new_cost': np.float64(11480186040.0), 'improvement': np.float64(46915850.0)}
# 181
# {'time': 2.0102409000101034, 'iteration': 76, 'move': '2-opt', 'i': 133, 'j': 153, 'old_cost': np.float64(11480186040.0), 'new_cost': np.float64(11475960990.0), 'improvement': np.float64(4225050.0)}
# 182
# {'time': 2.011692600004608, 'iteration': 77, 'move': 'swap', 'i': 137, 'j': 151, 'old_cost': np.float64(11475960990.0), 'new_cost': np.float64(11473920850.0), 'improvement': np.float64(2040140.0)}
# 183
# {'time': 2.013175500003854, 'iteration': 77, 'move': '2-opt', 'i': 177, 'j': 188, 'old_cost': np.float64(11473920850.0), 'new_cost': np.float64(11471630600.0), 'improvement': np.float64(2290250.0)}
# 184
# {'time': 2.0140152999956626, 'iteration': 77, 'move': 'relocate', 'i': 177, 'j': 38, 'old_cost': np.float64(11471630600.0), 'new_cost': np.float64(11399989220.0), 'improvement': np.float64(71641380.0)}
# 185
# {'time': 2.0178340999991633, 'iteration': 78, 'move': '2-opt', 'i': 125, 'j': 141, 'old_cost': np.float64(11399989220.0), 'new_cost': np.float64(11395559170.0), 'improvement': np.float64(4430050.0)}
# 186
# {'time': 2.020156499987934, 'iteration': 78, 'move': 'relocate', 'i': 125, 'j': 10, 'old_cost': np.float64(11395559170.0), 'new_cost': np.float64(11299170400.0), 'improvement': np.float64(96388770.0)}
# 187
# {'time': 2.0467032000015024, 'iteration': 79, 'move': 'relocate', 'i': 176, 'j': 60, 'old_cost': np.float64(11299170400.0), 'new_cost': np.float64(11257659910.0), 'improvement': np.float64(41510490.0)}
# 188
# {'time': 2.086085599992657, 'iteration': 79, 'move': '2-opt', 'i': 16, 'j': 36, 'old_cost': np.float64(11257659910.0), 'new_cost': np.float64(11196929490.0), 'improvement': np.float64(60730420.0)}
# 189
# {'time': 2.0934065000037663, 'iteration': 80, 'move': 'swap', 'i': 98, 'j': 132, 'old_cost': np.float64(11196929490.0), 'new_cost': np.float64(11186049310.0), 'improvement': np.float64(10880180.0)}
# 190
# {'time': 2.0991050000011455, 'iteration': 80, 'move': '2-opt', 'i': 16, 'j': 20, 'old_cost': np.float64(11186049310.0), 'new_cost': np.float64(11175689580.0), 'improvement': np.float64(10359730.0)}
# 191
# {'time': 2.1009391999978106, 'iteration': 80, 'move': 'relocate', 'i': 16, 'j': 21, 'old_cost': np.float64(11175689580.0), 'new_cost': np.float64(11170663320.0), 'improvement': np.float64(5026260.0)}
# 192
# {'time': 2.110955999989528, 'iteration': 81, 'move': '2-opt', 'i': 44, 'j': 47, 'old_cost': np.float64(11170663320.0), 'new_cost': np.float64(11168251560.0), 'improvement': np.float64(2411760.0)}
# 193
# {'time': 2.1124732999887783, 'iteration': 81, 'move': 'relocate', 'i': 44, 'j': 37, 'old_cost': np.float64(11168251560.0), 'new_cost': np.float64(11164467650.0), 'improvement': np.float64(3783910.0)}
# 194
# {'time': 2.1153716999979224, 'iteration': 81, 'move': 'swap', 'i': 108, 'j': 171, 'old_cost': np.float64(11164467650.0), 'new_cost': np.float64(11161323550.0), 'improvement': np.float64(3144100.0)}
# 195
# {'time': 2.1201897999853827, 'iteration': 82, 'move': 'relocate', 'i': 185, 'j': 95, 'old_cost': np.float64(11161323550.0), 'new_cost': np.float64(11136393340.0), 'improvement': np.float64(24930210.0)}
# 196
# {'time': 2.1233504000119865, 'iteration': 82, 'move': '2-opt', 'i': 49, 'j': 68, 'old_cost': np.float64(11136393340.0), 'new_cost': np.float64(10734861500.0), 'improvement': np.float64(401531840.0)}
# 197
# {'time': 2.12488139999914, 'iteration': 83, 'move': 'swap', 'i': 86, 'j': 90, 'old_cost': np.float64(10734861500.0), 'new_cost': np.float64(10724421410.0), 'improvement': np.float64(10440090.0)}
# 198
# {'time': 2.1259103000047617, 'iteration': 83, 'move': '2-opt', 'i': 0, 'j': 7, 'old_cost': np.float64(10724421410.0), 'new_cost': np.float64(10706308510.0), 'improvement': np.float64(18112900.0)}
# 199
# {'time': 2.163473199994769, 'iteration': 84, 'move': '2-opt', 'i': 153, 'j': 158, 'old_cost': np.float64(10706308510.0), 'new_cost': np.float64(10695283250.0), 'improvement': np.float64(11025260.0)}
# 200
# {'time': 2.175638499989873, 'iteration': 84, 'move': 'relocate', 'i': 153, 'j': 48, 'old_cost': np.float64(10695283250.0), 'new_cost': np.float64(10646224740.0), 'improvement': np.float64(49058510.0)}
# 201
# {'time': 2.205995199998142, 'iteration': 85, 'move': 'relocate', 'i': 199, 'j': 48, 'old_cost': np.float64(10646224740.0), 'new_cost': np.float64(10597267090.0), 'improvement': np.float64(48957650.0)}
# 202
# {'time': 2.2297339999931864, 'iteration': 86, 'move': 'swap', 'i': 169, 'j': 181, 'old_cost': np.float64(10597267090.0), 'new_cost': np.float64(10591416690.0), 'improvement': np.float64(5850400.0)}
# 203
# {'time': 2.232543899997836, 'iteration': 86, 'move': '2-opt', 'i': 133, 'j': 144, 'old_cost': np.float64(10591416690.0), 'new_cost': np.float64(10560231590.0), 'improvement': np.float64(31185100.0)}
# 204
# {'time': 2.238826299988432, 'iteration': 86, 'move': 'relocate', 'i': 133, 'j': 5, 'old_cost': np.float64(10560231590.0), 'new_cost': np.float64(10520634470.0), 'improvement': np.float64(39597120.0)}
# 205
# {'time': 2.250149600004079, 'iteration': 87, 'move': '2-opt', 'i': 41, 'j': 60, 'old_cost': np.float64(10520634470.0), 'new_cost': np.float64(10519081720.0), 'improvement': np.float64(1552750.0)}
# 206
# {'time': 2.254539899993688, 'iteration': 87, 'move': 'relocate', 'i': 41, 'j': 58, 'old_cost': np.float64(10519081720.0), 'new_cost': np.float64(10515769330.0), 'improvement': np.float64(3312390.0)}
# 207
# {'time': 2.2911898999882396, 'iteration': 88, 'move': 'relocate', 'i': 9, 'j': 4, 'old_cost': np.float64(10515769330.0), 'new_cost': np.float64(10503571620.0), 'improvement': np.float64(12197710.0)}
# 208
# {'time': 2.2937933999928646, 'iteration': 88, 'move': 'swap', 'i': 162, 'j': 172, 'old_cost': np.float64(10503571620.0), 'new_cost': np.float64(10500308790.0), 'improvement': np.float64(3262830.0)}
# 209
# {'time': 2.297130899998592, 'iteration': 88, 'move': '2-opt', 'i': 7, 'j': 20, 'old_cost': np.float64(10500308790.0), 'new_cost': np.float64(10497901850.0), 'improvement': np.float64(2406940.0)}
# 210
# {'time': 2.299054500006605, 'iteration': 89, 'move': 'swap', 'i': 42, 'j': 55, 'old_cost': np.float64(10497901850.0), 'new_cost': np.float64(10484252700.0), 'improvement': np.float64(13649150.0)}
# 211
# {'time': 2.380471300013596, 'iteration': 89, 'move': 'relocate', 'i': 10, 'j': 1, 'old_cost': np.float64(10484252700.0), 'new_cost': np.float64(10483796300.0), 'improvement': np.float64(456400.0)}
# 212
# {'time': 2.400362199987285, 'iteration': 90, 'move': '2-opt', 'i': 46, 'j': 61, 'old_cost': np.float64(10483796300.0), 'new_cost': np.float64(10472799140.0), 'improvement': np.float64(10997160.0)}
# 213
# {'time': 2.4200945000047795, 'iteration': 90, 'move': 'relocate', 'i': 46, 'j': 24, 'old_cost': np.float64(10472799140.0), 'new_cost': np.float64(10457340520.0), 'improvement': np.float64(15458620.0)}
# 214
# {'time': 2.438446899992414, 'iteration': 91, 'move': 'relocate', 'i': 20, 'j': 6, 'old_cost': np.float64(10457340520.0), 'new_cost': np.float64(10453752000.0), 'improvement': np.float64(3588520.0)}
# 215
# {'time': 2.447868399991421, 'iteration': 91, 'move': 'swap', 'i': 47, 'j': 180, 'old_cost': np.float64(10453752000.0), 'new_cost': np.float64(10453217060.0), 'improvement': np.float64(534940.0)}
# 216
# {'time': 2.450071700004628, 'iteration': 91, 'move': '2-opt', 'i': 89, 'j': 109, 'old_cost': np.float64(10453217060.0), 'new_cost': np.float64(10436050290.0), 'improvement': np.float64(17166770.0)}
# 217
# {'time': 2.4518948000040837, 'iteration': 92, 'move': 'swap', 'i': 110, 'j': 126, 'old_cost': np.float64(10436050290.0), 'new_cost': np.float64(10415409990.0), 'improvement': np.float64(20640300.0)}
# 218
# {'time': 2.48969039999065, 'iteration': 92, 'move': 'relocate', 'i': 28, 'j': 20, 'old_cost': np.float64(10415409990.0), 'new_cost': np.float64(10402610460.0), 'improvement': np.float64(12799530.0)}
# 219
# {'time': 2.49436899999273, 'iteration': 93, 'move': '2-opt', 'i': 158, 'j': 188, 'old_cost': np.float64(10402610460.0), 'new_cost': np.float64(10396360490.0), 'improvement': np.float64(6249970.0)}
# 220
# {'time': 2.4968203000025824, 'iteration': 93, 'move': 'relocate', 'i': 158, 'j': 22, 'old_cost': np.float64(10396360490.0), 'new_cost': np.float64(10366882520.0), 'improvement': np.float64(29477970.0)}
# 221
# {'time': 2.508247699995991, 'iteration': 94, 'move': 'relocate', 'i': 129, 'j': 37, 'old_cost': np.float64(10366882520.0), 'new_cost': np.float64(10319841560.0), 'improvement': np.float64(47040960.0)}
# 222
# {'time': 2.5097667000081856, 'iteration': 94, 'move': 'swap', 'i': 93, 'j': 97, 'old_cost': np.float64(10319841560.0), 'new_cost': np.float64(10312372010.0), 'improvement': np.float64(7469550.0)}
# 223
# {'time': 2.533500199991977, 'iteration': 95, 'move': 'swap', 'i': 129, 'j': 145, 'old_cost': np.float64(10312372010.0), 'new_cost': np.float64(10309761770.0), 'improvement': np.float64(2610240.0)}
# 224
# {'time': 2.5381584000133444, 'iteration': 95, 'move': '2-opt', 'i': 129, 'j': 135, 'old_cost': np.float64(10309761770.0), 'new_cost': np.float64(10308961870.0), 'improvement': np.float64(799900.0)}
# 225
# {'time': 2.5416732000012416, 'iteration': 95, 'move': 'relocate', 'i': 129, 'j': 42, 'old_cost': np.float64(10308961870.0), 'new_cost': np.float64(10298750450.0), 'improvement': np.float64(10211420.0)}
# 226
# {'time': 2.547943399986252, 'iteration': 96, 'move': '2-opt', 'i': 78, 'j': 81, 'old_cost': np.float64(10298750450.0), 'new_cost': np.float64(10289590370.0), 'improvement': np.float64(9160080.0)}
# 227
# {'time': 2.5495137000107206, 'iteration': 96, 'move': 'relocate', 'i': 78, 'j': 11, 'old_cost': np.float64(10289590370.0), 'new_cost': np.float64(10274605570.0), 'improvement': np.float64(14984800.0)}
# 228
# {'time': 2.5662125000089873, 'iteration': 97, 'move': 'relocate', 'i': 93, 'j': 178, 'old_cost': np.float64(10274605570.0), 'new_cost': np.float64(10264490290.0), 'improvement': np.float64(10115280.0)}
# 229
# {'time': 2.56768499998725, 'iteration': 97, 'move': 'swap', 'i': 38, 'j': 75, 'old_cost': np.float64(10264490290.0), 'new_cost': np.float64(10238148320.0), 'improvement': np.float64(26341970.0)}
# 230
# {'time': 2.596837699995376, 'iteration': 98, 'move': 'swap', 'i': 106, 'j': 177, 'old_cost': np.float64(10238148320.0), 'new_cost': np.float64(10218187830.0), 'improvement': np.float64(19960490.0)}
# 231
# {'time': 2.599759400007315, 'iteration': 98, 'move': '2-opt', 'i': 70, 'j': 86, 'old_cost': np.float64(10218187830.0), 'new_cost': np.float64(10203718000.0), 'improvement': np.float64(14469830.0)}
# 232
# {'time': 2.602980800002115, 'iteration': 98, 'move': 'relocate', 'i': 70, 'j': 11, 'old_cost': np.float64(10203718000.0), 'new_cost': np.float64(10154624290.0), 'improvement': np.float64(49093710.0)}
# 233
# {'time': 2.605627300014021, 'iteration': 99, 'move': '2-opt', 'i': 176, 'j': 180, 'old_cost': np.float64(10154624290.0), 'new_cost': np.float64(10148023980.0), 'improvement': np.float64(6600310.0)}
# 234
# {'time': 2.6065070999902673, 'iteration': 99, 'move': 'relocate', 'i': 176, 'j': 6, 'old_cost': np.float64(10148023980.0), 'new_cost': np.float64(10046211230.0), 'improvement': np.float64(101812750.0)}
# 235
# {'time': 2.643344599986449, 'iteration': 100, 'move': 'relocate', 'i': 108, 'j': 34, 'old_cost': np.float64(10046211230.0), 'new_cost': np.float64(10023386270.0), 'improvement': np.float64(22824960.0)}
# 236
# ...
# 2413
# {'time': 119.59993039999972, 'iteration': 1382, 'move': 'swap', 'i': 81, 'j': 93, 'old_cost': np.float64(89828170.0), 'new_cost': np.float64(89048520.0), 'improvement': np.float64(779650.0)}
# 2414
# {'time': 119.65612100000726, 'iteration': 1383, 'move': '2-opt', 'i': 44, 'j': 46, 'old_cost': np.float64(89048520.0), 'new_cost': np.float64(88842330.0), 'improvement': np.float64(206190.0)}
# 2415
# {'time': 120.0243996999925, 'iteration': 1384, 'move': 'relocate', 'i': 9, 'j': 6, 'old_cost': np.float64(88842330.0), 'new_cost': np.float64(87584980.0), 'improvement': np.float64(1257350.0)}
# 2416
# {'time': 120.20789439999498, 'iteration': 1385, 'move': 'swap', 'i': 84, 'j': 93, 'old_cost': np.float64(87584980.0), 'new_cost': np.float64(87238400.0), 'improvement': np.float64(346580.0)}
# 2417
# {'time': 120.3199578000058, 'iteration': 1386, 'move': '2-opt', 'i': 49, 'j': 51, 'old_cost': np.float64(87238400.0), 'new_cost': np.float64(87234400.0), 'improvement': np.float64(4000.0)}
# 2418
# {'time': 120.44495820000884, 'iteration': 1387, 'move': 'relocate', 'i': 44, 'j': 42, 'old_cost': np.float64(87234400.0), 'new_cost': np.float64(86569950.0), 'improvement': np.float64(664450.0)}
# 2419
# {'time': 120.74781510001048, 'iteration': 1388, 'move': 'swap', 'i': 83, 'j': 84, 'old_cost': np.float64(86569950.0), 'new_cost': np.float64(86304230.0), 'improvement': np.float64(265720.0)}
# 2420
# {'time': 120.85212759999558, 'iteration': 1389, 'move': '2-opt', 'i': 50, 'j': 51, 'old_cost': np.float64(86304230.0), 'new_cost': np.float64(86168510.0), 'improvement': np.float64(135720.0)}
# 2421
# {'time': 121.24146990000736, 'iteration': 1390, 'move': 'relocate', 'i': 123, 'j': 117, 'old_cost': np.float64(86168510.0), 'new_cost': np.float64(84637910.0), 'improvement': np.float64(1530600.0)}
# 2422
# {'time': 121.33565150000504, 'iteration': 1391, 'move': 'swap', 'i': 115, 'j': 116, 'old_cost': np.float64(84637910.0), 'new_cost': np.float64(83943270.0), 'improvement': np.float64(694640.0)}
# 2423
# {'time': 121.76330309998593, 'iteration': 1392, 'move': '2-opt', 'i': 45, 'j': 46, 'old_cost': np.float64(83943270.0), 'new_cost': np.float64(83614370.0), 'improvement': np.float64(328900.0)}
# 2424
# {'time': 121.83543080001255, 'iteration': 1393, 'move': 'relocate', 'i': 29, 'j': 27, 'old_cost': np.float64(83614370.0), 'new_cost': np.float64(82643650.0), 'improvement': np.float64(970720.0)}
# 2425
# {'time': 121.96619129998726, 'iteration': 1394, 'move': 'swap', 'i': 110, 'j': 116, 'old_cost': np.float64(82643650.0), 'new_cost': np.float64(82471200.0), 'improvement': np.float64(172450.0)}
# 2426
# {'time': 122.76447970001027, 'iteration': 1395, 'move': '2-opt', 'i': 127, 'j': 129, 'old_cost': np.float64(82471200.0), 'new_cost': np.float64(82198490.0), 'improvement': np.float64(272710.0)}
# 2427
# {'time': 123.2184843000141, 'iteration': 1396, 'move': 'relocate', 'i': 58, 'j': 53, 'old_cost': np.float64(82198490.0), 'new_cost': np.float64(80063750.0), 'improvement': np.float64(2134740.0)}
# 2428
# {'time': 123.55619269999443, 'iteration': 1397, 'move': 'swap', 'i': 146, 'j': 149, 'old_cost': np.float64(80063750.0), 'new_cost': np.float64(78998460.0), 'improvement': np.float64(1065290.0)}
# 2429
# {'time': 123.66962160001276, 'iteration': 1398, 'move': '2-opt', 'i': 82, 'j': 83, 'old_cost': np.float64(78998460.0), 'new_cost': np.float64(78411730.0), 'improvement': np.float64(586730.0)}
# 2430
# {'time': 123.82030029999441, 'iteration': 1399, 'move': 'relocate', 'i': 117, 'j': 116, 'old_cost': np.float64(78411730.0), 'new_cost': np.float64(78162810.0), 'improvement': np.float64(248920.0)}
# 2431
# {'time': 124.22049860001425, 'iteration': 1400, 'move': 'swap', 'i': 115, 'j': 117, 'old_cost': np.float64(78162810.0), 'new_cost': np.float64(77626860.0), 'improvement': np.float64(535950.0)}
# 2432
# {'time': 125.69829229998868, 'iteration': 1401, 'move': '2-opt', 'i': 176, 'j': 178, 'old_cost': np.float64(77626860.0), 'new_cost': np.float64(77462930.0), 'improvement': np.float64(163930.0)}
# 2433
# {'time': 125.788146100007, 'iteration': 1402, 'move': 'relocate', 'i': 105, 'j': 104, 'old_cost': np.float64(77462930.0), 'new_cost': np.float64(76053460.0), 'improvement': np.float64(1409470.0)}
# 2434
# {'time': 126.61921040000743, 'iteration': 1403, 'move': 'swap', 'i': 104, 'j': 115, 'old_cost': np.float64(76053460.0), 'new_cost': np.float64(75481010.0), 'improvement': np.float64(572450.0)}
# 2435
# {'time': 127.7454746000003, 'iteration': 1404, 'move': '2-opt', 'i': 92, 'j': 93, 'old_cost': np.float64(75481010.0), 'new_cost': np.float64(75476470.0), 'improvement': np.float64(4540.0)}
# 2436
# {'time': 127.91000420000637, 'iteration': 1405, 'move': 'relocate', 'i': 115, 'j': 106, 'old_cost': np.float64(75476470.0), 'new_cost': np.float64(72390430.0), 'improvement': np.float64(3086040.0)}
# 2437
# {'time': 128.56844120001188, 'iteration': 1406, 'move': 'swap', 'i': 91, 'j': 92, 'old_cost': np.float64(72390430.0), 'new_cost': np.float64(71104360.0), 'improvement': np.float64(1286070.0)}
# 2438
# {'time': 128.59526030000416, 'iteration': 1406, 'move': 'relocate', 'i': 54, 'j': 46, 'old_cost': np.float64(71104360.0), 'new_cost': np.float64(69801270.0), 'improvement': np.float64(1303090.0)}
# 2439
# {'time': 128.8159724000143, 'iteration': 1407, 'move': '2-opt', 'i': 46, 'j': 47, 'old_cost': np.float64(69801270.0), 'new_cost': np.float64(68720000.0), 'improvement': np.float64(1081270.0)}
# 2440
# {'time': 129.09444169999915, 'iteration': 1408, 'move': 'relocate', 'i': 117, 'j': 116, 'old_cost': np.float64(68720000.0), 'new_cost': np.float64(68230410.0), 'improvement': np.float64(489590.0)}
# 2441
# {'time': 129.67044429999078, 'iteration': 1409, 'move': 'swap', 'i': 98, 'j': 104, 'old_cost': np.float64(68230410.0), 'new_cost': np.float64(67864130.0), 'improvement': np.float64(366280.0)}
# 2442
# {'time': 130.01775319999433, 'iteration': 1410, 'move': '2-opt', 'i': 91, 'j': 92, 'old_cost': np.float64(67864130.0), 'new_cost': np.float64(66578060.0), 'improvement': np.float64(1286070.0)}
# 2443
# {'time': 130.89581359998556, 'iteration': 1411, 'move': 'relocate', 'i': 132, 'j': 129, 'old_cost': np.float64(66578060.0), 'new_cost': np.float64(66171350.0), 'improvement': np.float64(406710.0)}
# 2444
# {'time': 131.4776944000041, 'iteration': 1412, 'move': 'swap', 'i': 90, 'j': 91, 'old_cost': np.float64(66171350.0), 'new_cost': np.float64(64746600.0), 'improvement': np.float64(1424750.0)}
# 2445
# {'time': 133.87460370000917, 'iteration': 1413, 'move': '2-opt', 'i': 177, 'j': 178, 'old_cost': np.float64(64746600.0), 'new_cost': np.float64(64390620.0), 'improvement': np.float64(355980.0)}
# 2446
# {'time': 134.4975429000042, 'iteration': 1414, 'move': 'relocate', 'i': 104, 'j': 99, 'old_cost': np.float64(64390620.0), 'new_cost': np.float64(62913960.0), 'improvement': np.float64(1476660.0)}
# 2447
# {'time': 134.7358971000067, 'iteration': 1415, 'move': 'swap', 'i': 89, 'j': 90, 'old_cost': np.float64(62913960.0), 'new_cost': np.float64(62487060.0), 'improvement': np.float64(426900.0)}
# 2448
# {'time': 136.23028930000146, 'iteration': 1416, 'move': '2-opt', 'i': 105, 'j': 106, 'old_cost': np.float64(62487060.0), 'new_cost': np.float64(60777590.0), 'improvement': np.float64(1709470.0)}
# 2449
# {'time': 136.4185167000105, 'iteration': 1417, 'move': 'relocate', 'i': 113, 'j': 105, 'old_cost': np.float64(60777590.0), 'new_cost': np.float64(56900580.0), 'improvement': np.float64(3877010.0)}
# 2450
# {'time': 136.69574890000513, 'iteration': 1418, 'move': 'swap', 'i': 55, 'j': 61, 'old_cost': np.float64(56900580.0), 'new_cost': np.float64(56164600.0), 'improvement': np.float64(735980.0)}
# 2451
# {'time': 136.72444389999146, 'iteration': 1418, 'move': 'relocate', 'i': 63, 'j': 58, 'old_cost': np.float64(56164600.0), 'new_cost': np.float64(55779990.0), 'improvement': np.float64(384610.0)}
# 2452
# {'time': 137.4411540000001, 'iteration': 1419, 'move': '2-opt', 'i': 101, 'j': 102, 'old_cost': np.float64(55779990.0), 'new_cost': np.float64(54827620.0), 'improvement': np.float64(952370.0)}
# 2453
# {'time': 137.87033370000427, 'iteration': 1420, 'move': 'relocate', 'i': 98, 'j': 91, 'old_cost': np.float64(54827620.0), 'new_cost': np.float64(52104430.0), 'improvement': np.float64(2723190.0)}
# 2454
# {'time': 137.90701409999747, 'iteration': 1421, 'move': 'swap', 'i': 88, 'j': 89, 'old_cost': np.float64(52104430.0), 'new_cost': np.float64(51548690.0), 'improvement': np.float64(555740.0)}
# 2455
# {'time': 138.2715288999898, 'iteration': 1422, 'move': '2-opt', 'i': 101, 'j': 102, 'old_cost': np.float64(51548690.0), 'new_cost': np.float64(51388060.0), 'improvement': np.float64(160630.0)}
# 2456
# {'time': 138.43148400000064, 'iteration': 1423, 'move': 'relocate', 'i': 94, 'j': 93, 'old_cost': np.float64(51388060.0), 'new_cost': np.float64(51382770.0), 'improvement': np.float64(5290.0)}
# 2457
# {'time': 139.812583299994, 'iteration': 1424, 'move': 'swap', 'i': 91, 'j': 92, 'old_cost': np.float64(51382770.0), 'new_cost': np.float64(50421780.0), 'improvement': np.float64(960990.0)}
# 2458
# {'time': 140.26242390001426, 'iteration': 1425, 'move': '2-opt', 'i': 58, 'j': 59, 'old_cost': np.float64(50421780.0), 'new_cost': np.float64(48606330.0), 'improvement': np.float64(1815450.0)}
# 2459
# {'time': 141.32626609998988, 'iteration': 1426, 'move': 'relocate', 'i': 88, 'j': 85, 'old_cost': np.float64(48606330.0), 'new_cost': np.float64(47180430.0), 'improvement': np.float64(1425900.0)}
# 2460
# {'time': 142.41662110001198, 'iteration': 1427, 'move': 'swap', 'i': 77, 'j': 78, 'old_cost': np.float64(47180430.0), 'new_cost': np.float64(46994790.0), 'improvement': np.float64(185640.0)}
# 2461
# {'time': 143.23647520001396, 'iteration': 1428, 'move': '2-opt', 'i': 128, 'j': 130, 'old_cost': np.float64(46994790.0), 'new_cost': np.float64(46465570.0), 'improvement': np.float64(529220.0)}
# 2462
# {'time': 143.83842300000833, 'iteration': 1429, 'move': 'relocate', 'i': 122, 'j': 120, 'old_cost': np.float64(46465570.0), 'new_cost': np.float64(45391240.0), 'improvement': np.float64(1074330.0)}
# 2463
# {'time': 144.64332060000743, 'iteration': 1430, 'move': 'swap', 'i': 93, 'j': 94, 'old_cost': np.float64(45391240.0), 'new_cost': np.float64(43871280.0), 'improvement': np.float64(1519960.0)}
# 2464
# {'time': 147.19120589998784, 'iteration': 1431, 'move': '2-opt', 'i': 129, 'j': 130, 'old_cost': np.float64(43871280.0), 'new_cost': np.float64(41691860.0), 'improvement': np.float64(2179420.0)}
# 2465
# {'time': 148.58257790000062, 'iteration': 1432, 'move': 'relocate', 'i': 137, 'j': 136, 'old_cost': np.float64(41691860.0), 'new_cost': np.float64(41292700.0), 'improvement': np.float64(399160.0)}
# 2466
# {'time': 148.83370920000016, 'iteration': 1433, 'move': 'swap', 'i': 59, 'j': 62, 'old_cost': np.float64(41292700.0), 'new_cost': np.float64(40623340.0), 'improvement': np.float64(669360.0)}
# 2467
# {'time': 150.95862819999456, 'iteration': 1434, 'move': '2-opt', 'i': 62, 'j': 63, 'old_cost': np.float64(40623340.0), 'new_cost': np.float64(40566340.0), 'improvement': np.float64(57000.0)}
# 2468
# {'time': 151.43109259998892, 'iteration': 1435, 'move': 'relocate', 'i': 63, 'j': 60, 'old_cost': np.float64(40566340.0), 'new_cost': np.float64(37911140.0), 'improvement': np.float64(2655200.0)}
# 2469
# {'time': 158.44407540000975, 'iteration': 1436, 'move': 'relocate', 'i': 149, 'j': 146, 'old_cost': np.float64(37911140.0), 'new_cost': np.float64(36437330.0), 'improvement': np.float64(1473810.0)}
# 2470
# {'time': 159.7835783000046, 'iteration': 1437, 'move': '2-opt', 'i': 146, 'j': 147, 'old_cost': np.float64(36437330.0), 'new_cost': np.float64(35837920.0), 'improvement': np.float64(599410.0)}
# 2471
# {'time': 160.18127289999393, 'iteration': 1438, 'move': 'relocate', 'i': 59, 'j': 56, 'old_cost': np.float64(35837920.0), 'new_cost': np.float64(34282010.0), 'improvement': np.float64(1555910.0)}
# 2472
# {'time': 164.25033979999716, 'iteration': 1439, 'move': 'swap', 'i': 55, 'j': 56, 'old_cost': np.float64(34282010.0), 'new_cost': np.float64(33692470.0), 'improvement': np.float64(589540.0)}
# 2473
# {'time': 171.21005439999863, 'iteration': 1440, 'move': 'relocate', 'i': 68, 'j': 66, 'old_cost': np.float64(33692470.0), 'new_cost': np.float64(32464700.0), 'improvement': np.float64(1227770.0)}
# 2474
# {'time': 174.13185529998736, 'iteration': 1441, 'move': 'relocate', 'i': 164, 'j': 160, 'old_cost': np.float64(32464700.0), 'new_cost': np.float64(30620480.0), 'improvement': np.float64(1844220.0)}
# 2475
# {'time': 176.8729205999989, 'iteration': 1442, 'move': 'swap', 'i': 77, 'j': 78, 'old_cost': np.float64(30620480.0), 'new_cost': np.float64(30568120.0), 'improvement': np.float64(52360.0)}
# 2476
# {'time': 183.57447170000523, 'iteration': 1443, 'move': 'relocate', 'i': 55, 'j': 49, 'old_cost': np.float64(30568120.0), 'new_cost': np.float64(30289740.0), 'improvement': np.float64(278380.0)}
# 2477
# {'time': 184.8850065000006, 'iteration': 1444, 'move': 'relocate', 'i': 7, 'j': 2, 'old_cost': np.float64(30289740.0), 'new_cost': np.float64(27593420.0), 'improvement': np.float64(2696320.0)}
# 2478
# {'time': 185.07398620000458, 'iteration': 1445, 'move': 'swap', 'i': 48, 'j': 50, 'old_cost': np.float64(27593420.0), 'new_cost': np.float64(27565430.0), 'improvement': np.float64(27990.0)}
# 2479
# {'time': 185.30337229999714, 'iteration': 1446, 'move': '2-opt', 'i': 52, 'j': 53, 'old_cost': np.float64(27565430.0), 'new_cost': np.float64(27036150.0), 'improvement': np.float64(529280.0)}
# 2480
# {'time': 185.5520508000045, 'iteration': 1447, 'move': 'relocate', 'i': 53, 'j': 51, 'old_cost': np.float64(27036150.0), 'new_cost': np.float64(26931150.0), 'improvement': np.float64(105000.0)}
# 2481
# {'time': 189.09082039998611, 'iteration': 1448, 'move': 'swap', 'i': 49, 'j': 50, 'old_cost': np.float64(26931150.0), 'new_cost': np.float64(25661410.0), 'improvement': np.float64(1269740.0)}
# 2482
# {'time': 191.99124130001292, 'iteration': 1449, 'move': '2-opt', 'i': 51, 'j': 52, 'old_cost': np.float64(25661410.0), 'new_cost': np.float64(25591780.0), 'improvement': np.float64(69630.0)}
# 2483
# {'time': 195.77593800000614, 'iteration': 1450, 'move': 'relocate', 'i': 109, 'j': 95, 'old_cost': np.float64(25591780.0), 'new_cost': np.float64(22452360.0), 'improvement': np.float64(3139420.0)}
# 2484
# {'time': 196.62186330000986, 'iteration': 1451, 'move': 'swap', 'i': 94, 'j': 96, 'old_cost': np.float64(22452360.0), 'new_cost': np.float64(21745220.0), 'improvement': np.float64(707140.0)}
# 2485
# {'time': 196.7608276999963, 'iteration': 1452, 'move': '2-opt', 'i': 102, 'j': 103, 'old_cost': np.float64(21745220.0), 'new_cost': np.float64(21398850.0), 'improvement': np.float64(346370.0)}
# 2486
# {'time': 198.19535759999417, 'iteration': 1453, 'move': 'relocate', 'i': 193, 'j': 176, 'old_cost': np.float64(21398850.0), 'new_cost': np.float64(13734820.0), 'improvement': np.float64(7664030.0)}
# 2487
# {'time': 199.02357570000459, 'iteration': 1454, 'move': 'swap', 'i': 95, 'j': 96, 'old_cost': np.float64(13734820.0), 'new_cost': np.float64(13311910.0), 'improvement': np.float64(422910.0)}
# 2488
# {'time': 199.53606829998898, 'iteration': 1455, 'move': '2-opt', 'i': 110, 'j': 111, 'old_cost': np.float64(13311910.0), 'new_cost': np.float64(12736920.0), 'improvement': np.float64(574990.0)}
# 2489
# {'time': 200.9735878999927, 'iteration': 1456, 'move': 'relocate', 'i': 49, 'j': 48, 'old_cost': np.float64(12736920.0), 'new_cost': np.float64(12578920.0), 'improvement': np.float64(158000.0)}
# 2490
# {'time': 205.07954760000575, 'iteration': 1457, 'move': 'swap', 'i': 94, 'j': 95, 'old_cost': np.float64(12578920.0), 'new_cost': np.float64(10975960.0), 'improvement': np.float64(1602960.0)}
# 2491
# {'time': 208.3472244000004, 'iteration': 1458, 'move': '2-opt', 'i': 102, 'j': 103, 'old_cost': np.float64(10975960.0), 'new_cost': np.float64(10840330.0), 'improvement': np.float64(135630.0)}
# 2492
# {'time': 211.39231570000993, 'iteration': 1459, 'move': 'relocate', 'i': 77, 'j': 60, 'old_cost': np.float64(10840330.0), 'new_cost': np.float64(104250.0), 'improvement': np.float64(10736080.0)}

# %%
print(improve_indi.route_computing[5])
print(improve_indi.route_computing[7])
# Out:
# 0.0
# 584.0
